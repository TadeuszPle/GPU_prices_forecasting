# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('FACT_GPU_PRICE.csv')
df['Date']=pd.to_datetime(df['TimeId'].astype(str), format="%Y%m%d")
df.set_index('Date', inplace=True)

# %%
df
# Out:
#             ProdId    TimeId  RegionId  MerchantId   Price_USD  Price_Original
# Date
# 2014-09-17       1  20140917         4          32  601.738413         463.900
# 2014-09-18       1  20140918         4          32  551.885276         425.870
# 2014-09-19       1  20140919         4          32  548.098896         424.530
# 2014-09-20       1  20140920         4          32  545.093860         424.530
# 2014-09-21       1  20140921         4          32  544.674245         424.530
# ...            ...       ...       ...         ...         ...             ...
# 2018-03-12    2054  20180312         4          32  261.254103         212.090
# 2018-03-13    2054  20180313         4          32  263.058996         212.090
# 2018-03-14    2054  20180314         4          32  261.517908         211.415
# 2018-03-15    2054  20180315         4          32  260.038547         211.150
# 2018-03-16    2054  20180316         4          32  259.480216         211.165
#
# ...

# %%
df['Price_USD'].plot(figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dfCrypto=pd.read_csv('FACT_CRYPTO_RATE.csv')
dfCrypto['Date']=pd.to_datetime(dfCrypto['TimeId'].astype(str), format="%Y%m%d")
dfCrypto.set_index('Date', inplace=True)
dfCrypto
# Out:
#             CodeId    TimeId      Open     Close      High       Low
# Date
# 2017-11-03       1  20171103  0.021418  0.022628  0.023213  0.019827
# 2017-11-04       1  20171104  0.022641  0.022022  0.023849  0.021970
# 2017-11-05       1  20171105  0.022054  0.020635  0.023006  0.020635
# 2017-11-06       1  20171106  0.020977  0.021881  0.023609  0.020534
# 2017-11-07       1  20171107  0.021846  0.022195  0.023347  0.021414
# ...            ...       ...       ...       ...       ...       ...
# 2018-04-09      15  20180409  0.501201  0.491855  0.512142  0.482573
# 2018-04-10      15  20180410  0.492134  0.491931  0.493645  0.482839
# 2018-04-11      15  20180411  0.492568  0.539506  0.548455  0.489026
# 2018-04-12      15  20180412  0.538657  0.628737  0.644518  0.506543
# 2018-04-13      15  20180413  0.630093  0.638087  0.693112  0.605816
#
# [15844 rows x 6 columns]

# %%
dfCrypto['Close'].plot(figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='Date'>
